# %% [markdown]
# ## 1º Change in top military spenders

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Carrega os dados da planilha militaryexpenditures.csv e exclui da coluna Name os valores "World" e "High income", pois são genéricos

milexp_df = pd.read_csv('./military_expenditure/militaryexpenditure.csv', sep=',')
milexp_df = milexp_df.loc[~milexp_df['Name'].isin(['World', 'High income'])]
milexp_df.head(10)
# Out:
#                    Name Code                            Type  \
# 0                 Aruba  ABW                         Country
# 1           Afghanistan  AFG                         Country
# 2                Angola  AGO                         Country
# 3               Albania  ALB                         Country
# 4               Andorra  AND                         Country
# 5            Arab World  ARB  Regions Clubbed Geographically
# 6  United Arab Emirates  ARE                         Country
# 7             Argentina  ARG                         Country
# 8               Armenia  ARM                         Country
# 9        American Samoa  ASM          Semi Autonomous Region
#
#                        Indicator Name  1960  1961         1962         1963  \
# 0  Military expenditure (current USD)   NaN   NaN          NaN          NaN
# 1  Military expenditure (current USD)   NaN   NaN          NaN          NaN
# ...

# %%
# Cria um novo DataFrame com os 3 maiores gastadores de cada ano e reseta os índices

three_spenders_df = milexp_df.groupby('year').apply(lambda x: x.nlargest(2, 'value')).reset_index(drop=True)
three_spenders_df.head()
# Out:
# /tmp/ipykernel_158436/2311419448.py:3: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   three_spenders_df = milexp_df.groupby('year').apply(lambda x: x.nlargest(2, 'value')).reset_index(drop=True)
#                         name code                          type  \
# 0               OECD members  OED  Regions Clubbed Economically
# 1  Post-demographic dividend  PST  Regions Clubbed Economically
# 2               OECD members  OED  Regions Clubbed Economically
# 3  Post-demographic dividend  PST  Regions Clubbed Economically
# 4               OECD members  OED  Regions Clubbed Economically
#
#                        indicator_name    year         value
# ...

# %%
plt.plot(three_spenders_df['year'], three_spenders_df['value'])
plt.ylabel('Bilhões de US$')
plt.title('Título')
plt.show()
